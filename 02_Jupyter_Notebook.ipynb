# %% [markdown]
# - 课程 02 Jupyter Notebook为什么是现代Python的必学技术？
#
# # 什么是Jupyter Notebook
# - 按照Jupyter 创始人 Fernando Pérez的说法，他最初的梦想是做一个综合 Ju （Julia）、Py （Python）和 R 三种科学运算语言的计算工具平台，所以将其命名为Ju-Py-te-R。发展到现在，Jupyter 已经成为一个几乎支持所有语言，能够把软件代码、**计算输出、解释文档、多媒体资源整合在一起的多功能**科学运算平台。Google Colab是谷歌定制的Jupyter版本！Jupyter NoteBook在学术界和工业界已经构建了强大的影响力
# ------
# - Jupyter Notebook 引进了Cell的概念，每次实验可以只跑一小个Cell里的代码；并且，所见即所得，在代码下面立刻就可以看到结果。这样强的互动性，让Python研究员可以专注于问题本身，不被繁杂的工具链所累，不用在命令行直接切换，所有科研工作都能在Jupyter上完成。

# %% [markdown]
# # Jupyter NoteBook 初体验

# %%
#! /bin/bash 
# 使用使用的python环境中的pip去安装以来，不然识别不到。
! /usr/local/bin/python3.10 -m pip install matplotlib
# Out:
# 536.62s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 794.0 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.8/260.8 kB 305.7 kB/s eta 0:00:0000:0100:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 584.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 888.1 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# Check versions
import sys
import matplotlib

print ("Python is:", sys.version)
print ("Matplotlib is:", matplotlib.__version__)

# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Python is: 3.10.13 (main, Aug 24 2023, 12:59:26) [Clang 15.0.0 (clang-1500.1.0.2.5)]
# Matplotlib is: 3.9.0

# %%
# Make a plot
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

N = M = 200
X, Y = np.ogrid[0:20:N*1j, 0:20:M*1j]
data = np.sin(np.pi * X*2 / 20) * np.cos(np.pi * Y*2 / 20)

im = ax.imshow(data, extent=[0, 200, 0, 200])
fig.colorbar(im, ax=ax, shrink=0.8)

ax.set_xlabel("X", fontsize=18)
ax.set_ylabel("Y", fontsize=18)
# Out:
# Text(0, 0.5, 'Y')
